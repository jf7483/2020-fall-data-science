# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
# Import the libraries you'll need here.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import scipy.stats as stats

# %% [markdown]
# # Load the csv file into a pandas dataframe.

# %%
# Load the csv file into a pandas dataframe.
cars_df = pd.read_csv('data/cars.csv')

cars_df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %%
cars_df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.

print(cars_df.duplicated().sum())
# Out:
# 720

# %%
#  2. Modify our df to have all duplicate rows removed. 
# inplace = True makes it so that it reassigns back to the original df 

cars_df.drop_duplicates(inplace = True)

print(cars_df.shape)
# Out:
# (11194, 15)

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate 
# rows again.

print(cars_df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?

cars_df.isnull().sum()

# we can conclude that column Engine HP has the most null values
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long (aka how many rows) our dataframe is.

print(cars_df.shape)
# Out:
# (11194, 15)

# %%
# * Remove any row that has a null value in it. 
# what is the difference between how = 'any' and how = 'all'? 

cars_df.dropna(inplace = True)

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

cars_df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ### Make a bar chart that displays how many time each brand of car appears in this data.
# _Brand of car is the `Make` of the car._

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 

cars_df['Make'].value_counts().plot(kind = 'bar', figsize=(9,8))

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.

# %%
# Make the cart more legible, by making it a horizontal bar chart and changing the figure size.

cars_df['Make'].value_counts().plot(kind = 'barh', figsize=(7,10))

# %% [markdown]
# ### Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.

gb = cars_df.groupby('Year')['MSRP'].mean()
#ax = sns.lineplot(data = cars_df, x='Year', y='MSRP');
gb.plot(kind = 'line', figsize=(12,7))

# %% [markdown]
# # It seems as though in the years before 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for
# every year before 2000 make it 10x the original MSRP.

# %%
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.

c1 = cars_df['Year'] <= 2000

cars_df['adjusted_price'] = np.where(c1, cars_df['MSRP'] * 10, cars_df['MSRP'])

cars_df.head(3)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# 0      Compact         Coupe           26        19        3916  46135
# 1      Compact   Convertible           28        19        3916  40650
# 2      Compact         Coupe           28        20        3916  36350
#
#    adjusted_price
# 0           46135
# 1           40650
# 2           36350

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Replot the new adjusted price and make the y-axis start at 0 and go up to 100,000

ax = sns.lineplot(data = cars_df, x='Year', y='adjusted_price');
ax.set(ylim=(0, 100000));

# %% [markdown]
# # What are the top 5 car makers make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5.
# * Use our `adjusted_price` column for this

# %%
# What are the top 5 car makers make the most expensive cars on average. 

#cars_df.sort_values(by = 'adjusted_price', ascending = False)

gb = cars_df.groupby('Make')['MSRP'].mean()
gb = gb.round(2)
gb.nlargest(n = 5)

#ax = sns.lineplot(data = cars_df, x='Year', y='MSRP');
#gb.plot(kind = 'line', figsize=(7,10))


# come back to this 
#cars_df.nlargest(n = 5, columns = 'adjusted_price', keep = 'first')
# Out:
# Make
# Bugatti        1757223.67
# Maybach         546221.88
# Rolls-Royce     351130.65
# Lamborghini     331567.31
# Bentley         247169.32
# Name: MSRP, dtype: float64

# %% [markdown]
# # What are the top 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?

gb = cars_df.groupby('Make')['highway MPG'].median()
gb.nlargest(n = 5)
# Out:
# Make
# Alfa Romeo    34
# FIAT          33
# Honda         32
# Scion         32
# Volkswagen    32
# Name: highway MPG, dtype: int64

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# come back to this 

c1 = cars_df['Make'] == 'Chevrolet'
c2 = cars_df['Make'] == 'Ford'
c3 = cars_df['Make'] == 'Toyota'

new_df = cars_df[c1 | c2 | c3]

sns.distplot(new_df['adjusted_price'])

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG

sns.scatterplot(data = cars_df, x = 'Engine HP', y = 'highway MPG',
                palette='Dark2')

# %% [markdown]
# # Remove any statisical outliers from Engine HP and highway MPG and plot the result.
# * Statisical outliers meaning values that are further than 3 standard deviations from the mean
# * Create a new columns for z-scores for each 'Engine HP' and 'highway MPG' named 'Engine HP_zscore' and 'highway MPG_zscore'
# * Calculate the z-scores for each of our target columns.
# * Make sure you set the z-scores to be their absolute values.
# * Create condition masks for when either of those absolute values are greater than 3.
#
# * Create a new dataframe that is a copy of our dataframe using df.copy()
#
# * Using our new dataframe
#     * Filter out all Engine HP Z-Scores that are greater than 3
#     * Filter out all Highway MPG z-scores that are greater than 3.
#     * Make the same scatterplot plotting the relationship of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any statisical outliers from Engine HP and highway MPG

f, axes = plt.subplots(1, 2, figsize=(13,5))
ax = sns.boxplot(data=cars_df, x='Engine HP', ax=axes[0]);
ax = sns.boxplot(data=cars_df, x='highway MPG', ax=axes[1]);

# %%
cars_df = cars_df.dropna()

# Create a list of just our numerical columns
numerical_cols = ['highway MPG', 'Engine HP']

# Create an empty list that we will store our new z-score column names in
z_score_cols = []

# Loop through the numerical columns
for col in numerical_cols:
    
    # Create a new column name that is the old column name + 'z_score'
    new_col_name = col + '_zscore'
    
    # Call the zscore function on the numerical column in our dataframe
    # And set it equal to our new column name.
    cars_df[new_col_name] = stats.stats.zscore(cars_df[col])
    
    # Convert all values into absolute values. 
    cars_df[new_col_name] = abs(cars_df[new_col_name])
    
    # Append the new column name our our z_score_cols list for easier access for later.
    z_score_cols.append(new_col_name)
    

cars_df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# ...

# %%
new_df = cars_df.copy()

c1 = new_df['Engine HP_zscore'] < 3
c2 = new_df['highway MPG_zscore'] < 3


new_df = new_df[c1]
new_df = new_df[c2]
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# # Make our selection mask, so anwhere the zscore is greater than 3
# condition = cars_df[z_score_cols] < 3

# # Say if any of the rows is true, set to true, else set to false
# condition = condition.any(axis=1)

# # Apply our condition mask
# new_df = cars_df[condition]

# # Print our results
# new_df.head()

# %%
f, axes = plt.subplots(1, 2, figsize=(13,5))

ax = sns.boxplot(data=new_df, x='Engine HP', ax=axes[0]);
ax = sns.boxplot(data=new_df, x='highway MPG', ax=axes[1]);

# %%
c1 = new_df['Engine HP'] > 800 
new_df[c1]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP, adjusted_price, highway MPG_zscore, Engine HP_zscore]
# Index: []

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?
print('The higher the Engine HP the linear highway MPG is')
# Out:
# The higher the Engine HP the linear highway MPG is

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
sns.pairplot(cars_df)

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).
print('city MPG and Highway MPG')
# Out:
# city MPG and Highway MPG

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8

sns.heatmap(cars_df.corr(), annot=True, cmap='Spectral')

# %%
print('It looks like Engine HP has a strong relationship with Engine Cyliders and I think that is because the'
     + 'cylinder is the power unit of the engine ')
# Out:
# It looks like Engine HP has a strong relationship with Engine Cyliders and I think that is because thecylinder is the power unit of the engine

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
# * Using subplots, display the histogram of adjusted_price for 'Ford' and 'Toyota' appear on charts side by side.
#     * `f, axes = plt.subplots(1, 2, figsize=(13,5))`

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
